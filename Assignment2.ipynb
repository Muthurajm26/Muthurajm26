# %% [markdown]
# 2. Load the dataset

# %%
import pandas as pd
import numpy as np
a=pd.read_csv('Churn_Modelling.csv')
print(a)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
a.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# 3. Perform Below Visualizations
#
#     Univariate Analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.scatter(a.index,a['Age'])
plt.show()

# %%
sns.scatterplot(x=a.index,y=a['Age'],hue=a['CreditScore'])

# %% [markdown]
# Bi-Variate Analysis

# %%
plt.scatter(a.Age,a.Gender)
plt.xlabel('Age')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
#    Multi-Variate Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D
a=pd.read_csv('Churn_Modelling.csv')
a.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
a=a[['Age','CreditScore','Tenure']]
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
n=100
ax.scatter(a['Age'],a['CreditScore'],a['Tenure'],color="red")
ax.set_xlabel("Age")
ax.set_ylabel("CreditScore")
ax.set_zlabel("Tenure")
plt.show()

# %% [markdown]
# 4. Perform descriptive statistics on the dataset

# %%
import statistics as st
st.mean(a.Age)
# Out:
# 38.9218

# %%
import statistics as st
st.mode(a.Age)
# Out:
# 37

# %%
import statistics as st
st.median(a.Age)
# Out:
# 37.0

# %% [markdown]
# 5. Handle the Missing values

# %%
a.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
a.notnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender   Age  \
# 0          True        True     True         True       True    True  True
# 1          True        True     True         True       True    True  True
# 2          True        True     True         True       True    True  True
# 3          True        True     True         True       True    True  True
# 4          True        True     True         True       True    True  True
# ...         ...         ...      ...          ...        ...     ...   ...
# 9995       True        True     True         True       True    True  True
# 9996       True        True     True         True       True    True  True
# 9997       True        True     True         True       True    True  True
# 9998       True        True     True         True       True    True  True
# 9999       True        True     True         True       True    True  True
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# 6. Find the outliers and replace the outliers

# %%
import pandas as pd
import numpy as np
a=pd.read_csv('Churn_Modelling.csv')
print(a)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
b=['RowNumber','CustomerId','CreditScore','Age']
c=a.boxplot(b)
print(c)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Hence we checked the null value it contains all 0, so we don't want to remove the outlier

# %%
a.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# 7. Check for Categorical columns and perform encoding

# %%
a.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
a["Age"].value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
k={"Surname":{"Hargrave":"magesh","Hill":"muthu","Onio":"raguraman","Boni":"abastin"}}
m=a.replace(k)
m.head()
# Out:
#    RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602     magesh          619    France  Female   42
# 1          2    15647311      muthu          608     Spain  Female   41
# 2          3    15619304  raguraman          502    France  Female   42
# 3          4    15701354    abastin          699    France  Female   39
# 4          5    15737888   Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
m.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# 8. Split the data into dependent and independent variables
#
# Dependent

# %%
a.iloc[:5,:9].values
# Out:
# array([[1, 15634602, 'Hargrave', 619, 'France', 'Female', 42, 2, 0.0],
#        [2, 15647311, 'Hill', 608, 'Spain', 'Female', 41, 1, 83807.86],
#        [3, 15619304, 'Onio', 502, 'France', 'Female', 42, 8, 159660.8],
#        [4, 15701354, 'Boni', 699, 'France', 'Female', 39, 1, 0.0],
#        [5, 15737888, 'Mitchell', 850, 'Spain', 'Female', 43, 2,
#         125510.82]], dtype=object)

# %% [markdown]
# Independent

# %%
a.iloc[:,9].values
# Out:
# array([1, 1, 3, ..., 1, 2, 1])

# %% [markdown]
# 9. Scale the independent variables

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
a=read_csv('Churn_Modelling.csv')
a.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x=a[['RowNumber','CustomerId','CreditScore','Age','Tenure','Balance']]
scale=StandardScaler()
scaledx=scale.fit_transform(x)
print(scaledx)
# Out:
# [[-1.73187761 -0.78321342 -0.32622142  0.29351742 -1.04175968 -1.22584767]
#  [-1.7315312  -0.60653412 -0.44003595  0.19816383 -1.38753759  0.11735002]
#  [-1.73118479 -0.99588476 -1.53679418  0.29351742  1.03290776  1.33305335]
#  ...
#  [ 1.73118479 -1.47928179  0.60498839 -0.27860412  0.68712986 -1.22584767]
#  [ 1.7315312  -0.11935577  1.25683526  0.29351742 -0.69598177 -0.02260751]
#  [ 1.73187761 -0.87055909  1.46377078 -1.04143285 -0.35020386  0.85996499]]

# %% [markdown]
# 10. Split the data into training and testing

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
a=pd.read_csv('Churn_Modelling.csv')
training_data=a.sample(frac=0.8,random_state=25)
testing_data=a.drop(training_data.index)
print(training_data.shape[0])
print(testing_data.shape[0])
# Out:
# 8000
# 2000
